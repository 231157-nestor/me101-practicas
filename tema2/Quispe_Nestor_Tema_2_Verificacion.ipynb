# %%
import pandas as pd
import numpy as np
print("Entorno me101 funcionando correctamente")
print("pandas:&quot;, pd.__version__, &quot;| numpy: ", np.__version__)
# Out:
# Entorno me101 funcionando correctamente
# pandas:&quot;, pd.__version__, &quot;| numpy:  2.4.6
